# %%
# What are stocks and bonds
# Stocks something that a person invests into and gains ownership or shares of that something
#In stocks, there is dividend
#Return Guarantee in Stocks not there
#Stocsk let voting rights in the company

#Bonds: something a person tends to give loan to a company or institution, and gets monthly or annual based interest
#In Bonds, there is interest in it
#Return Gurantee in Bonds
#Prefential treatment are given only when bond matures

#Step1: Dataset: Yahoo Finance or Finance Google
#Step2: Resampling
#Step3: Moving Windows: how stock did, weekly, monthly etc
#Step4: Volatility: which stocks are stable or volatile

# %%
import pandas as pd
amd = pd.read_csv("https://raw.githubusercontent.com/DivyaThakur24/Stock-Market-Analysis/master/AMD.csv", 
                 header = 0, index_col = 'Date', parse_dates = True)
amd

#before using header = 0 and rest,
#we could see that Date was shown as an individual col not an index, and we want Date to be an Index
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2003-12-31  15.200000  15.200000  14.810000  14.900000  14.900000   7395900
# 2004-01-02  15.100000  15.110000  14.770000  14.860000  14.860000   8220700
# 2004-01-05  15.050000  15.270000  15.010000  15.200000  15.200000   9156000
# 2004-01-06  15.210000  15.820000  15.050000  15.610000  15.610000  14592200
# 2004-01-07  15.780000  15.990000  15.490000  15.660000  15.660000  15329300
# ...               ...        ...        ...        ...        ...       ...
# 2019-09-09  30.930000  31.180000  30.240000  30.500000  30.500000  54413200
# 2019-09-10  30.219999  30.379999  29.770000  30.230000  30.230000  48604800
# 2019-09-11  30.379999  30.430000  29.510000  29.760000  29.760000  50631700
# 2019-09-12  30.080000  30.840000  29.950001  30.209999  30.209999  53618300
# 2019-09-13  30.270000  30.850000  29.950001  30.690001  30.690001  47758800
#
# [3953 rows x 6 columns]

# %%
amd.head(n = 3)
# Out:
#              Open   High    Low  Close  Adj Close   Volume
# Date
# 2003-12-31  15.20  15.20  14.81  14.90      14.90  7395900
# 2004-01-02  15.10  15.11  14.77  14.86      14.86  8220700
# 2004-01-05  15.05  15.27  15.01  15.20      15.20  9156000

# %%
amd.tail(n = 3)
# Out:
#                  Open   High        Low      Close  Adj Close    Volume
# Date
# 2019-09-11  30.379999  30.43  29.510000  29.760000  29.760000  50631700
# 2019-09-12  30.080000  30.84  29.950001  30.209999  30.209999  53618300
# 2019-09-13  30.270000  30.85  29.950001  30.690001  30.690001  47758800

# %%
#above shows date is from 2003 31 till 2019 13

# %%
# !pip install pandas_datareader
#this way u dont have to download data, you can directly read data from its location, with following codes

# %%
import pandas_datareader as pdr
import datetime

# %%
#Getting particular data
nvda = pdr.get_data_yahoo('NVDA',
                         start = datetime.datetime(2004, 1, 1), #Year, Month and Date
                         end = datetime.datetime(2019, 9, 15))

# %%
#Getting particular data
qcom = pdr.get_data_yahoo('QCOM',
                         start = datetime.datetime(2004, 1, 1),
                         end = datetime.datetime(2019, 9, 15))

# %%
intc = pdr.get_data_yahoo('INTC',
                         start = datetime.datetime(2004, 1, 1),
                         end = datetime.datetime(2019, 9, 15))

# %%
ibm = pdr.get_data_yahoo('IBM',
                         start = datetime.datetime(2004, 1, 1),
                         end = datetime.datetime(2019, 9, 15))

# %%
type(nvda)
# Out:
# pandas.core.frame.DataFrame

# %%
nvda.head(n = 3)
# Out:
#                 High       Low      Open     Close      Volume  Adj Close
# Date
# 2004-01-02  7.963333  7.693333  7.856667  7.693333  10910400.0   7.075438
# 2004-01-05  7.996666  7.740000  7.810000  7.943333  14382300.0   7.305359
# 2004-01-06  8.376667  7.883333  7.920000  8.266666  27333600.0   7.602723

# %%
ibm = pdr.get_data_yahoo('IBM',
                         start = datetime.datetime(2004, 1, 1),
                         end = datetime.datetime(2019, 9, 15))

# %%
ibm.describe()
#total of 3953 stocks have been traded
#50% of data has been traded for 141
#max has been 215
# Out:
#               High          Low         Open        Close        Volume  \
# count  3952.000000  3952.000000  3952.000000  3952.000000  3.952000e+03
# mean    138.698742   136.614502   137.604284   137.679357  5.652437e+06
# std      38.481923    38.207525    38.351100    38.347755  3.084721e+06
# min      73.690002    69.500000    72.529999    71.739998  1.027500e+06
# 25%     103.000000   100.205000   101.309999   101.645000  3.657450e+06
# 50%     141.010002   139.090004   139.959999   140.059998  4.853000e+06
# 75%     167.459999   165.110004   166.267502   166.252499  6.680950e+06
# max     215.899994   214.300003   215.380005   215.800003  3.077070e+07
#
#          Adj Close
# count  3952.000000
# mean    103.306871
# std      33.802357
# min      46.632313
# 25%      68.640907
# 50%     114.946362
# 75%     132.657806
# max     158.909164

# %%
#lets check number of columns NVDA has and what cols are there
nvda.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
nvda.index
# Out:
# DatetimeIndex(['2004-01-02', '2004-01-05', '2004-01-06', '2004-01-07',
#                '2004-01-08', '2004-01-09', '2004-01-12', '2004-01-13',
#                '2004-01-14', '2004-01-15',
#                ...
#                '2019-08-30', '2019-09-03', '2019-09-04', '2019-09-05',
#                '2019-09-06', '2019-09-09', '2019-09-10', '2019-09-11',
#                '2019-09-12', '2019-09-13'],
#               dtype='datetime64[ns]', name='Date', length=3952, freq=None)

# %%
nvda.shape
# Out:
# (3952, 6)

# %%
# Time Series Data
#is a squence of numerical data points taken at successive equally spaced points in time.
# In investing, a time series tracks the movement of stock price, over a specified period of time

# %%
import matplotlib.pyplot as plt

# %matplotlib inline #all our plots are imbedded in our notebook
# Out:
# UsageError: unrecognized arguments: #all our plots are imbedded in our notebook

# %%
import matplotlib.dates as mdates

# %%
plt.plot(ibm.index, ibm['Adj Close'])
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.gca().xaxis.set_major_locator(mdates.YearLocator()) #data is arranged as per Year
plt.grid(True)
plt.xticks(rotation = 90) #to read data more properly
plt.show()
#with this code, u can view all the years data.
#Its showing annual data from 2004 to 2019
#in 2009, due to recession, it traded low
#in 2016 it did well with 160
#Similarly u can plot for other companies as well, and u would be needing subplots

# %%
#Subplots
f, ax = plt.subplots(2, 2, figsize=(10,10), sharex=True)#here there are two rows and 2 colns, fig: 10 in length and 10 in height and 4 companies sharing x axis
f.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y')) #formatted as per year
f.gca().xaxis.set_major_locator(mdates.YearLocator()) #making sure Year data is displayed on x axis

ax[0,0].plot(nvda.index, nvda['Adj Close'], color='r')
ax[0,0].grid(True)
ax[0,0].tick_params(labelrotation=90)
ax[0,0].set_title('NVIDIA');

ax[0,1].plot(intc.index, intc['Adj Close'], color='g')
ax[0,1].grid(True)
ax[0,1].tick_params(labelrotation=90)
ax[0,1].set_title('INTEL');

ax[1,0].plot(qcom.index, qcom['Adj Close'], color='b')
ax[1,0].grid(True)
ax[1,0].tick_params(labelrotation=90)
ax[1,0].set_title('QUALCOMM');

ax[1,1].plot(amd.index, amd['Adj Close'], color='y')
ax[1,1].grid(True)
ax[1,1].tick_params(labelrotation=90)
ax[1,1].set_title('AMD');

#The Graphs are sharing the x Axis

# %%
# Step 2: Resampling:
#involves changing the frequency of your time series observations
#Frequency can be changed into two ways:
#1. Down Sampling: That is where you decrease the frequency of the samples:eg: Days into Months
    #we have daily data, convert them to Months
#2. Up-Sampling: Where you increase the frequency of the samples: Ex: Minutes into Seconds

# %%
# Zooming In
ibm_18 = ibm.loc[pd.Timestamp('2018-01-01'):pd.Timestamp('2018-12-31')]
#1st of Jan 2018 to 31st Dec 2018

plt.plot(ibm_18.index, ibm_18['Adj Close'])
#indices against the 'Adj Close', we are plotting

plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
#COntaining both Year and Month

plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

#Sharp decline for IBM

# %%
#Subplots
#now i am doing above same steps, for all other companies
#here i have done down sampling, 
#bse i had day to day day data, 
f, ax = plt.subplots(2, 2, figsize=(10,10), sharex=True, sharey=True)
f.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
f.gca().xaxis.set_major_locator(mdates.MonthLocator())

nvda_18 = nvda.loc[pd.Timestamp('2017-11-01'):pd.Timestamp('2018-12-31')]
ax[0,0].plot(nvda_18.index, nvda_18['Adj Close'], '.', color='r')#the dot, is for scatterung plot
ax[0,0].grid(True)
ax[0,0].tick_params(labelrotation=90)
ax[0,0].set_title('NVIDIA');

intc_18 = intc.loc[pd.Timestamp('2017-11-01'):pd.Timestamp('2018-12-31')]
ax[0,1].plot(intc_18.index, intc_18['Adj Close'], '.' ,color='g')
ax[0,1].grid(True)
ax[0,1].tick_params(labelrotation=90)
ax[0,1].set_title('INTEL');

qcom_18 = qcom.loc[pd.Timestamp('2017-11-01'):pd.Timestamp('2018-12-31')]
ax[1,0].plot(qcom_18.index, qcom_18['Adj Close'], '.' ,color='b')
ax[1,0].grid(True)
ax[1,0].tick_params(labelrotation=90)
ax[1,0].set_title('QUALCOMM');

amd_18 = amd.loc[pd.Timestamp('2017-11-01'):pd.Timestamp('2018-12-31')]
ax[1,1].plot(amd_18.index, amd_18['Adj Close'], '.' ,color='y')
ax[1,1].grid(True)
ax[1,1].tick_params(labelrotation=90)
ax[1,1].set_title('AMD');

# %%
#Step 2: Resampling(Quartely)
#now resampling through monthly data
monthly_nvda_18 = nvda_18.resample('4M').mean()

plt.scatter(monthly_nvda_18.index, monthly_nvda_18['Adj Close'])
#instead of using '.', i can use scatter directly, whatever suits you

plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()
#its showing oct till jan me mean value of 210
#it has clubbed feb till may, mean value of 221 and so on
#we see sharp increase in stock prices and then fall

# %%
#Subplots
#will do same thing quartely as of above for all other companies
f, ax = plt.subplots(2, 2, figsize=(10,10), sharex=True, sharey=True)

monthly_nvda_18 = nvda_18.resample('4M').mean()
ax[0,0].scatter(monthly_nvda_18.index, monthly_nvda_18['Adj Close'], color='r')
ax[0,0].grid(True)
ax[0,0].tick_params(labelrotation=90)
ax[0,0].set_title('NVIDIA');

monthly_intc_18 = intc_18.resample('4M').mean()
ax[0,1].scatter(monthly_intc_18.index, monthly_intc_18['Adj Close'], color='g')
ax[0,1].grid(True)
ax[0,1].tick_params(labelrotation=90)
ax[0,1].set_title('INTEL');

monthly_qcom_18 = qcom_18.resample('4M').mean()
ax[1,0].scatter(monthly_qcom_18.index, monthly_qcom_18['Adj Close'], color='b')
ax[1,0].grid(True)
ax[1,0].tick_params(labelrotation=90)
ax[1,0].set_title('QUALCOMM');

monthly_amd_18 = amd_18.resample('4M').mean()
ax[1,1].scatter(monthly_amd_18.index, monthly_amd_18['Adj Close'], color='y')
ax[1,1].grid(True)
ax[1,1].tick_params(labelrotation=90)
ax[1,1].set_title('AMD');

# %%
# Step 2: Resampling (Weekly)

ibm_19 = ibm.loc[pd.Timestamp('2019-01-15'):pd.Timestamp('2019-09-15')]# 9 months in hand

weekly_ibm_19 = ibm_19.resample('W').mean()
weekly_ibm_19.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2019-01-20  122.765001  121.227501  121.592499  122.340002   4596750.0
# 2019-01-27  131.612503  128.927496  130.042500  130.477499  11036600.0
# 2019-02-03  135.034000  133.304004  134.162000  134.300003   4717140.0
# 2019-02-10  135.170001  133.478000  134.082001  134.792004   4374880.0
# 2019-02-17  137.012000  135.756003  136.221997  136.414001   3459760.0
#
#              Adj Close
# Date
# 2019-01-20  110.923536
# 2019-01-27  118.301661
# 2019-02-03  121.767456
# 2019-02-10  122.777444
# 2019-02-17  125.125256

# %%
plt.plot(weekly_ibm_19.index, weekly_ibm_19['Adj Close'], '-o')#the bigger dot, a way of visualizing
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))#Year, Month, Date
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %%
#Subplots
#for all other companies, weekly
nvda_19 = nvda.loc[pd.Timestamp('2019-01-15'):pd.Timestamp('2019-09-15')]
weekly_nvda_19 = nvda_19.resample('W').mean()

intc_19 = intc.loc[pd.Timestamp('2019-01-15'):pd.Timestamp('2019-09-15')]
weekly_intc_19 = intc_19.resample('W').mean()

qcom_19 = qcom.loc[pd.Timestamp('2019-01-15'):pd.Timestamp('2019-09-15')]
weekly_qcom_19 = qcom_19.resample('W').mean()

amd_19 = amd.loc[pd.Timestamp('2019-01-15'):pd.Timestamp('2019-09-15')]
weekly_amd_19 = amd_19.resample('W').mean()

f, ax = plt.subplots(2, 2, figsize=(10,10), sharex=True, sharey=True)
ax[0,0].plot(weekly_nvda_19.index, weekly_nvda_19['Adj Close'], '-o', color='r')
ax[0,0].grid(True)
ax[0,0].tick_params(labelrotation=90)
ax[0,0].set_title('NVIDIA');

ax[0,1].plot(weekly_intc_19.index, weekly_intc_19['Adj Close'], '-o',color='g')
ax[0,1].grid(True)
ax[0,1].tick_params(labelrotation=90)
ax[0,1].set_title('INTEL');

ax[1,0].plot(weekly_qcom_19.index, weekly_qcom_19['Adj Close'],'-o', color='b')
ax[1,0].grid(True)
ax[1,0].tick_params(labelrotation=90)
ax[1,0].set_title('QUALCOMM');

ax[1,1].plot(weekly_amd_19.index, weekly_amd_19['Adj Close'], '-o', color='y')
ax[1,1].grid(True)
ax[1,1].tick_params(labelrotation=90)
ax[1,1].set_title('AMD');
#resampapling isnt giving good picture, 
#all companies are not on same level as the way we see it, difff prices
#for this, we need to see using 'MOVING AVERAGES'

# %%
# Analysing Difference between Levels (Resampling Weekly)
#MOVING AVERAGES
#person had rs 10 at start of the day and at end of day he earns rupees 50 
#another person: start of day has 100 and at end of day earns 120
#who earned more and in what percentage
#50 - 10 = 40
#120 - 100 = 20
#first person got greater share than person 2
#same thing for companies, we need to see open and close prices

ibm['diff'] = ibm['Open'] - ibm['Close'] 
ibm_diff = ibm.resample('W').mean() # resampling weekly
ibm_diff.tail(10)

#from diff col, we see ibm, stocks did pretty well, then they got low, -1.4
#then they were little higher, -0.04
#then they started making profit and so on
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2019-07-14  141.738000  140.230002  140.873999  140.870004  2638700.0
# 2019-07-21  146.647998  143.767999  144.426001  145.846002  6378680.0
# 2019-07-28  151.228000  149.198001  150.334003  150.380002  3358720.0
# 2019-08-04  151.565997  148.004001  149.747998  149.292004  4575360.0
# 2019-08-11  141.376001  137.595999  140.694000  139.366000  5724640.0
# 2019-08-18  134.712000  132.033997  133.526001  133.367996  4056560.0
# 2019-08-25  135.497998  132.826001  134.680005  133.236002  3300540.0
# 2019-09-01  133.530002  131.581998  132.489999  132.866000  3241580.0
# 2019-09-08  138.639996  136.747501  137.595005  137.990005  3166050.0
# 2019-09-15  144.457999  142.254004  143.358002  143.708002  3557600.0
#
#              Adj Close      diff
# Date
# 2019-07-14  130.747369  0.003995
# 2019-07-21  135.365814 -1.420001
# 2019-07-28  139.573999 -0.045999
# 2019-08-04  138.564188  0.455994
# ...

# %%
#plotting above in scatter plot with diff coln
plt.scatter(ibm_diff.loc['2019-01-01':'2019-09-15'].index, ibm_diff.loc['2019-01-01':'2019-09-15']['diff'])
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %%
#Subplots
#plotting for all other companies with diff col
nvda['diff'] = nvda['Open'] - nvda['Close']
nvda_diff = nvda.resample('W').mean()

intc['diff'] = intc['Open'] - intc['Close']
intc_diff = intc.resample('W').mean()

qcom['diff'] = qcom['Open'] - qcom['Close']
qcom_diff = qcom.resample('W').mean()

amd['diff'] = amd['Open'] - amd['Close']
amd_diff = amd.resample('W').mean()

f, ax = plt.subplots(2, 2, figsize=(10,10), sharex=True, sharey=True)

ax[0,0].scatter(nvda_diff.loc['2019-01-01':'2019-09-15'].index, nvda_diff.loc['2019-01-01':'2019-09-15']['diff']
, color='r')
ax[0,0].grid(True)
ax[0,0].tick_params(labelrotation=90)
ax[0,0].set_title('NVIDIA');

ax[0,1].scatter(intc_diff.loc['2019-01-01':'2019-09-15'].index, intc_diff.loc['2019-01-01':'2019-09-15']['diff']
, color='g')
ax[0,1].grid(True)
ax[0,1].tick_params(labelrotation=90)
ax[0,1].set_title('INTEL');

ax[1,0].scatter(qcom_diff.loc['2019-01-01':'2019-09-15'].index, qcom_diff.loc['2019-01-01':'2019-09-15']['diff']
, color='b')
ax[1,0].grid(True)
ax[1,0].tick_params(labelrotation=90)
ax[1,0].set_title('QUALCOMM');

ax[1,1].scatter(amd_diff.loc['2019-01-01':'2019-09-15'].index, amd_diff.loc['2019-01-01':'2019-09-15']['diff']
, color='y')
ax[1,1].grid(True)
ax[1,1].tick_params(labelrotation=90)
ax[1,1].set_title('AMD');
#Intel is constant

# %%
# Step 3: Moving Windows
# Moving Windows are there when you compute the statistic on a window of data
#represented by a particular period of time and then slide the window across the data by a specified interval.

#that way, statistic is continually calculated as long as the window falls first with in the dates of the T.S

#A rolling mean smoothens out short term flucuations and highlight longer term trends in data

#Inshort: your starting from home at slower speed, then you gradually increase your speed
#thats how moving windows work

# Daily Percentages
#suppose i take Adj Close 15 - 09 - 19 - Adj Close 14 - 09 - 19 % (daily percentages)

daily_close_ibm = ibm[['Adj Close']]

# Daily returns
daily_pct_change_ibm = daily_close_ibm.pct_change()

# Replace NA values with 0
daily_pct_change_ibm.fillna(0, inplace=True)

daily_pct_change_ibm.head()
# Out:
#             Adj Close
# Date
# 2004-01-02   0.000000
# 2004-01-05   0.016384
# 2004-01-06   0.000107
# 2004-01-07  -0.003009
# 2004-01-08   0.002803

# %%
daily_pct_change_ibm.hist(bins=50)

# Show the plot
plt.show()
#the stocks have not made profits more than 0.05 and havent lost more than -0.075

# %%
#we do this for NVDA and other companies
daily_close_nvda = nvda[['Adj Close']]

# Daily returns
daily_pct_change_nvda = daily_close_nvda.pct_change()

# Replace NA values with 0
daily_pct_change_nvda.fillna(0, inplace=True)

daily_close_intc = intc[['Adj Close']]

# Daily returns
daily_pct_change_intc = daily_close_intc.pct_change()

# Replace NA values with 0
daily_pct_change_intc.fillna(0, inplace=True)

daily_close_qcom = qcom[['Adj Close']]

# Daily returns
daily_pct_change_qcom = daily_close_qcom.pct_change()

# Replace NA values with 0
daily_pct_change_qcom.fillna(0, inplace=True)

daily_close_amd = amd[['Adj Close']]

# Daily returns
daily_pct_change_amd = daily_close_amd.pct_change()

# Replace NA values with 0
daily_pct_change_amd.fillna(0, inplace=True)

daily_pct_change_amd.head()
# Out:
#             Adj Close
# Date
# 2003-12-31   0.000000
# 2004-01-02  -0.002685
# 2004-01-05   0.022880
# 2004-01-06   0.026974
# 2004-01-07   0.003203

# %%
import seaborn as sns
sns.set()

# %%
import seaborn as sns
# Set up the matplotlib figure
f, axes = plt.subplots(2, 2, figsize=(12, 7))

# Plot a simple histogram with binsize determined automatically, plotting density plot
sns.distplot(daily_pct_change_nvda['Adj Close'], color="b", ax=axes[0, 0], axlabel='NVIDIA');

# Plot a kernel density estimate and rug plot
sns.distplot(daily_pct_change_intc['Adj Close'], color="r", ax=axes[0, 1], axlabel='INTEL');

# Plot a filled kernel density estimate
sns.distplot(daily_pct_change_qcom['Adj Close'], color="g", ax=axes[1, 0], axlabel='QUALCOMM');

# Plot a historgram and kernel density estimate
sns.distplot(daily_pct_change_amd['Adj Close'], color="m", ax=axes[1, 1], axlabel='AMD');
#for NVDIA,-0.4 means, for 40,000, nvda can suffer a loss of 4,000
#and gain 0.3 as 3000

#qualcom stocks are more stable
# Out:
# /Users/riteshtripathi/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/riteshtripathi/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Step 4: Volatality of Stocks in terms of variance
#The volatility of stock is a measurement of the change in variance in the returns of a stock over a specific
#period of time

#To compare the volatility of stock with another stock to get a feel for which may have less risk 
# or to a market index to examine the stock's volatility in the overall market

#Generally the higher the volatility, the riskier the investment in that stock

#if its volatility, you can risk more or gain more
import numpy as np

# %%
min_periods = 75 

# Calculate the volatility
vol = daily_pct_change_ibm.rolling(min_periods).std() * np.sqrt(min_periods) 
#i am getting variance of daily percentage values

vol.fillna(0,inplace=True)

vol.tail()
#we see ibm stocks are less volatile
# Out:
#             Adj Close
# Date
# 2019-09-09   0.127697
# 2019-09-10   0.125065
# 2019-09-11   0.125571
# 2019-09-12   0.124641
# 2019-09-13   0.124419

# %%
# Plot the volatility
vol.plot(figsize=(10, 8))

# Show the plot
plt.show()

# %%
# Rolling Means (Trends and Seasonality), this is to see for long term
#Variance gives you a better picture of volatility

ibm_adj_close_px = ibm['Adj Close']
# Short moving window rolling mean
ibm['42'] = ibm_adj_close_px.rolling(window=40).mean()
#here i am getting short term window
#40 will give me quaterly trend

# Long moving window rolling mean, long term window, this will give yearly trend
ibm['252'] = ibm_adj_close_px.rolling(window=252).mean()

# Plot the adjusted closing price, the short and long windows of rolling means
ibm[['Adj Close', '42', '252']].plot(title="IBM")

# Show plot
plt.show()

#same thing for ibm, i have done for nvda
nvda_adj_close_px = nvda['Adj Close']
# Short moving window rolling mean
nvda['42'] = nvda_adj_close_px.rolling(window=40).mean()

# Long moving window rolling mean
nvda['252'] = nvda_adj_close_px.rolling(window=252).mean()

# Plot the adjusted closing price, the short and long windows of rolling means
nvda[['Adj Close', '42', '252']].plot(title="NVIDIA")

# Show plot
plt.show()

#42 is the shorter window, if you have to invest in monthly or quarterly basis, invest in this stock
#252: if you want to invest in long term, then invest in this
#ibm was high in 2012 and 2013 and then a fall
#you can invest for long term in ibm for 1 or 2 years, as they are stable
#you can see trend and seasonality
#short window shows the trend
#longer window shows the seasonality

# %%
ibm.loc['2019-01-01':'2019-09-15'][['Adj Close', '42', '252']].plot(title="IBM in 2019");
nvda.loc['2019-01-01':'2019-09-15'][['Adj Close', '42', '252']].plot(title="NVIDIA in 2019");
#plotting both ibm and nvda in one chart

# %%
#in this way, you can decide whether to invest in those stocks or not, whether they are giving profits or not
#whether they are more or less volatile
#whether to invest in short or long term
